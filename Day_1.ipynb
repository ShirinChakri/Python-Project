# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# variable

# %%
a=2
b=6
print(a+b)
# Out:
# 8

# %% [markdown]
# variable

# %%
a=4
b=5
c=19
print("sum",a+b+c)
print("sub",a+b+c)
print("mul",a*b*c)
# Out:
# sum 28
# sub 28
# mul 380
